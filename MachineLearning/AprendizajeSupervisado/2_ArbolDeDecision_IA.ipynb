# %% [markdown]
# <a href="https://colab.research.google.com/github/dilp90/InteligenciaArtificial_y_RedesNeuronales_UANL_FIME/blob/main/MachineLearning/AprendizajeSupervisado/2_ArbolDeDecision_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Árbol de decisión**
#
# En esta libreta se entrena un árbol de decisión en el conjunto de datos Iris. Mas información:
# * https://scikit-learn.org/stable/auto_examples/datasets/plot_iris_dataset.html
# * https://archive.ics.uci.edu/dataset/53/iris

# %% [markdown]
# 1. Importar librerías.

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn import tree
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns
import numpy as np

# %% [markdown]
# 2. Cargar datos

# %%
iris = load_iris()
X = iris.data
y = iris.target

# %%
len(y)
# Out:
# 150

# %%
y[0]
# Out:
# np.int64(0)

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %% [markdown]
# 3. Preprocesamiento

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# 4. Selección y entrenamiento del modelo

# %%
clf = DecisionTreeClassifier()

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Exactitud del modelo en el entrenamiento.
train_accuracy = clf.score(X_train, y_train)
print(train_accuracy)
# Out:
# 1.0

# %% [markdown]
# 5. Prueba del modelo.

# %%
y_pred = clf.predict(X_test)

# %%
# Obtener la matriz de confusión
conf_matrix = confusion_matrix(y_test, y_pred)

# %%
# Mostrar la matriz de confusión de resultados de la prueba
plt.figure(figsize=(5,4))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=['setosa', 'versicolor', 'virginica'], yticklabels=['setosa', 'versicolor', 'virginica'])
plt.xlabel("Predicho")
plt.ylabel("Real")
plt.title("Matriz de Confusión (Prueba)")
plt.show()

# %%
#Predicción 1
print(y_pred[1])
print(y_test[1])
# Out:
# 0
# 0

# %%
#Predicción 2
print(y_pred[20])
print(y_test[20])
# Out:
# 0
# 0

# %%
#Predicción 3
print(y_pred[-1])
print(y_test[-1])
# Out:
# 0
# 0

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("Classification Report:\n", classification_report(y_test, y_pred, target_names=iris.target_names))
# Out:
# Accuracy: 1.0
# Classification Report:
#                precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      1.00      1.00        13
#    virginica       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %% [markdown]
# Visualización del árbol de decisión.

# %%
plt.figure(figsize=(20, 15))  # Increase figure size for better resolution
tree.plot_tree(clf, filled=True, feature_names=iris.feature_names, class_names=iris.target_names)
plt.title("Decision Tree for Iris Species Prediction")
plt.savefig("decision_tree.png", dpi=300)  # Increase DPI for better resolution
plt.show()
